# %% [markdown]
# <a href="https://colab.research.google.com/github/nlovoldegar/first-streamlit-app/blob/main/%5BNicole_Lovold_Egar%5DAssignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
from collections import Counter
from heapq import nlargest

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b6e66fc5-3f96-40d4-87f6-a5f25585a07a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b6e66fc5-3f96-40d4-87f6-a5f25585a07a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir ~/.kaggle/
# !cp kaggle.json ~/.kaggle/
# Out:
# mkdir: cannot create directory ‘/root/.kaggle/’: File exists

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ref                                                             title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# meirnizri/covid19-dataset                                       COVID-19 Dataset                                      5MB  2022-11-13 15:47:17           5773        173  1.0
# madhurpant/world-deaths-and-causes-1990-2019                    World Deaths and Causes (1990 - 2019)               442KB  2022-11-29 07:09:27            947         23  1.0
# thedevastator/jobs-dataset-from-glassdoor                       Salary Prediction                                     3MB  2022-11-16 13:52:31           3821         89  1.0
# ...

# %%
# !kaggle datasets download -d hamzafarooq50/hotel-listings-and-reviews/HotelListInLondon__en2019100120191005.csv
# Out:
# hotel-listings-and-reviews.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !ls
# Out:
# hotel-listings-and-reviews.zip	kaggle.json  sample_data

# %%
# !unzip HotelListInLondon__en2019100120191005.csv
# Out:
# unzip:  cannot find or open HotelListInLondon__en2019100120191005.csv, HotelListInLondon__en2019100120191005.csv.zip or HotelListInLondon__en2019100120191005.csv.ZIP.

# %%
import re

# %%
import nltk
nltk.download('punkt')

from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
nltk.download('stopwords')

from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
import os
import spacy
nlp = spacy.load("en_core_web_sm")
from spacy import displacy

# %%
text = """this is a base text"""

doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(doc, jupyter = True, style="ent")

# %%
stopwords = list(STOP_WORDS)
from string import punctuation
punctuation = punctuation+ '\n'

# %%
import pandas as pd

import scipy.spatial
import pickle as pkl

# %%
# !pip install -U sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 85 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 24.2 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 58.1 MB/s
# ...
#      |████████████████████████████████| 182 kB 64.3 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 40.0 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=337c0dee23d308043fea9e7d8e551559ceaa8759b340dc31bf3035156d3360b7
#   Stored in directory: /root/.cache/pip/wheels/5e/6f/8c/d88aec621f3f542d26fac0342bef5e693335d125f4e54aeffe
# Successfully built sentence-transformers
# ...

# %%
from sentence_transformers import SentenceTransformer

# %%
embedder = SentenceTransformer('all-MiniLM-L6-v2')
#embedder = SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
df = pd.read_csv("HotelListInLondon__en2019100120191005.csv")

# %%
# !kaggle datasets download -d hamzafarooq50/hotel-listings-and-reviews
# Out:
# hotel-listings-and-reviews.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
df.head()
# Out:
#    Unnamed: 0                                    hotel_name  \
# 0           0                  Travelodge London City hotel
# 1           1            Hampton by Hilton London Docklands
# 2           2                                Sunborn London
# 3           3                             The Walrus Hostel
# 4           4  Point A Hotel, London Kings Cross St Pancras
#
#                                                  url locality  reviews  \
# 0  http://www.tripadvisor.com/Hotel_Review-g18633...   London     1035
# 1  http://www.tripadvisor.com/Hotel_Review-g18633...   London      550
# 2  http://www.tripadvisor.com/Hotel_Review-g18633...   London     3558
# 3  http://www.tripadvisor.com/Hotel_Review-g18633...   London      585
# 4  http://www.tripadvisor.com/Hotel_Review-g18633...   London     6295
#
#    tripadvisor_rating     checkIn    checkOut price_per_night  \
# 0                 NaN  2019/10/01  2019/10/05             NaN
# ...

# %%
import pandas as pd
from tqdm import tqdm
from sentence_transformers import SentenceTransformer, util

# %%
df['hotel_name'].value_counts()
# Out:
# Travelodge London City hotel                      1
# Hampton by Hilton London Docklands                1
# hub by Premier Inn London Westminster Abbey       1
# Premier Inn London Hanger Lane Hotel              1
# Lansbury Heritage Hotel                           1
# Kensington Gardens Hotel                          1
# The Hide London                                   1
# Pelican London Hotel and Residence                1
# The Captain Cook                                  1
# The Lion & Key Hotel                              1
# DoubleTree by Hilton London Greenwich             1
# The Mad Hatter Hotel                              1
# Brit Hotels London Court                          1
# Ibis London Shepherds Bush - Hammersmith Hotel    1
# Hotel 55                                          1
# The Z Hotel City                                  1
# Ibis London Canning Town                          1
# Park Plaza London Park Royal                      1
# ...

# %%
df['hotel_name'].drop_duplicates()
# Out:
# 0                       Travelodge London City hotel
# 1                 Hampton by Hilton London Docklands
# 2                                     Sunborn London
# 3                                  The Walrus Hostel
# 4       Point A Hotel, London Kings Cross St Pancras
# 5                                   St. Athans Hotel
# 6                                 The W14 Kensington
# 7                       Z Hotel Tottenham Court Road
# 8                               The Westbridge Hotel
# 9                               Novotel London Excel
# 10                                     Montana Hotel
# 11                             Charlotte Guest House
# 12                         Holiday Inn London - West
# 13                      Park Plaza London Park Royal
# 14                          Ibis London Canning Town
# 15                                  The Z Hotel City
# 16                                          Hotel 55
# 17    Ibis London Shepherds Bush - Hammersmith Hotel
# ...

# %%
df_combined = df.sort_values(['hotel_name']).groupby('hotel_name', sort=False).url.apply(''.join).reset_index(name='url')

# %%
df_combined.head().T
# Out:
#                                                             0  \
# hotel_name                           Brit Hotels London Court
# url         http://www.tripadvisor.com/Hotel_Review-g18633...
#
#                                                             1  \
# hotel_name                              Charlotte Guest House
# url         http://www.tripadvisor.com/Hotel_Review-g18633...
#
#                                                             2  \
# hotel_name              DoubleTree by Hilton London Greenwich
# url         http://www.tripadvisor.com/Hotel_Review-g18633...
#
#                                                             3  \
# hotel_name                 Hampton by Hilton London Docklands
# url         http://www.tripadvisor.com/Hotel_Review-g18633...
#
#                                                             4
# hotel_name                          Holiday Inn London - West
# url         http://www.tripadvisor.com/Hotel_Review-g18633...

# %%
import re

df_combined['url'] = df_combined['url'].apply(lambda x: re.sub('[^a-zA-z0-9\s]','',x))

def lower_case(input_str):
    input_str = input_str.lower()
    return input_str

df_combined['url']= df_combined['url'].apply(lambda x: lower_case(x))

# %%
df = df_combined

# %%
df_sentences = df_combined.set_index("url")
df_sentences = df_sentences["hotel_name"].to_dict()
df_sentences_list = list(df_sentences.keys())
len(df_sentences_list)
# Out:
# 30

# %%
df_sentences.head()
# Out:
#                                                                                hotel_name
# url
# httpwwwtripadvisorcomhotel_reviewg186338d282813...               Brit Hotels London Court
# httpwwwtripadvisorcomhotel_reviewg186338d656240...                  Charlotte Guest House
# httpwwwtripadvisorcomhotel_reviewg186338d350729...  DoubleTree by Hilton London Greenwich
# httpwwwtripadvisorcomhotel_reviewg186338d120318...     Hampton by Hilton London Docklands
# httpwwwtripadvisorcomhotel_reviewg186338d313125...              Holiday Inn London - West

# %%
list(df_sentences.keys())[:5]
# Out:
# ['hotel_name']

# %%
import pandas as pd
from tqdm import tqdm
from sentence_transformers import SentenceTransformer, util

# %%
df_sentences_list = [str(d) for d in tqdm(df_sentences_list)]
# Out:
# 100%|██████████| 30/30 [00:00<00:00, 193285.90it/s]

# %%
# Converts each combined review and creates an embedding for each hotel
corpus = df_sentences_list
corpus_embeddings = embedder.encode(corpus,show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
corpus_embeddings[0].shape
# Out:
# (384,)

# %%
queries = ['Hotel with deals from expedia']
query_embeddings = embedder.encode(queries,show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import torch

# Query sentences:
queries = ['Hotel in london close to buckingham palace',
           'Hotel in london less than 200 per night']


# Find the closest 5 sentences of the corpus for each query sentence based on cosine similarity
top_k = min(5, len(corpus))
for query in queries:
    query_embedding = embedder.encode(query, convert_to_tensor=True)

    # We use cosine-similarity and torch.topk to find the highest 5 scores
    cos_scores = util.pytorch_cos_sim(query_embedding, corpus_embeddings)[0]
    top_results = torch.topk(cos_scores, k=top_k)

    print("\n\n======================\n\n")
    print("Query:", query)
    print("\nTop 5 most similar sentences in corpus:")

    for score, idx in zip(top_results[0], top_results[1]):
        print("(Score: {:.4f})".format(score))
        print(corpus[idx], "(Score: {:.4f})".format(score))
        row_dict = df.loc[df['url']== corpus[idx]]
        print("paper_id:  " , row_dict['hotel_name'] , "\n")
    # for idx, distance in results[0:closest_n]:
    #     print("Score:   ", "(Score: %.4f)" % (1-distance) , "\n" )
    #     print("Paragraph:   ", corpus[idx].strip(), "\n" )
    #     row_dict = df.loc[df['all_review']== corpus[idx]]
    #     print("paper_id:  " , row_dict['Hotel'] , "\n")

# %%
model = SentenceTransformer('sentence-transformers/paraphrase-xlm-r-multilingual-v1')
embeddings = model.encode(corpus)
#print(embeddings)
# Out:
# Downloading:   0%|          | 0.00/345 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/718 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/550 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
# Query sentences:
queries = ['Hotel in london less than 200 per night'
           ]

# Find the closest 5 sentences of the corpus for each query sentence based on cosine similarity
top_k = min(5, len(corpus))
for query in queries:
    
    query_embedding = model.encode(query, convert_to_tensor=True)

    # We use cosine-similarity and torch.topk to find the highest 5 scores
    cos_scores = util.pytorch_cos_sim(query_embedding, embeddings)[0]
    top_results = torch.topk(cos_scores, k=top_k)

    print("\n\n======================\n\n")
    print("Query:", query)
    print("\nTop 5 most similar sentences in corpus:")

    for score, idx in zip(top_results[0], top_results[1]):
        print("(Score: {:.4f})".format(score))
        print(corpus[idx], "(Score: {:.4f})".format(score))
        row_dict = df.loc[df['url']== corpus[idx]]
        print("paper_id:  " , row_dict['hotel_name'] , "\n")
# Out:
# ...
#
#
# Query: Hotel in london less than 200 per night
#
# Top 5 most similar sentences in corpus:
# (Score: 0.4801)
# httpwwwtripadvisorcomhotel_reviewg186338d282813reviewsbrit_hotels_london_courtlondon_englandhtml (Score: 0.4801)
# paper_id:   0    Brit Hotels London Court
# Name: hotel_name, dtype: object
#
# (Score: 0.4665)
# httpwwwtripadvisorcomhotel_reviewg186338d9608180reviewsthe_z_hotel_citylondon_englandhtml (Score: 0.4665)
# paper_id:   25    The Z Hotel City
# Name: hotel_name, dtype: object
#
# (Score: 0.4648)
# httpwwwtripadvisorcomhotel_reviewg186338d12938460reviewsibis_london_canning_townlondon_englandhtml (Score: 0.4648)
# paper_id:   6    Ibis London Canning Town
# Name: hotel_name, dtype: object
#
# (Score: 0.4550)
# httpwwwtripadvisorcomhotel_reviewg186338d313125reviewsholiday_inn_london_westlondon_englandhtml (Score: 0.4550)
# paper_id:   4    Holiday Inn London - West
# Name: hotel_name, dtype: object
#
# (Score: 0.4485)
# ...

# %%
hits = util.semantic_search(query_embedding, embeddings, top_k=5)
hits = hits[0]      #Get the hits for the first query
for hit in hits:
  print (hit)
  print("(Score: {:.4f})".format(hit['score']))
  print(corpus[hit['corpus_id']])
  row_dict = df.loc[df['url']== corpus[hit['corpus_id']]]
  print("paper_id:  " , row_dict['hotel_name'] , "\n")
# Out:
# {'corpus_id': 0, 'score': 0.48011037707328796}
# (Score: 0.4801)
# httpwwwtripadvisorcomhotel_reviewg186338d282813reviewsbrit_hotels_london_courtlondon_englandhtml
# paper_id:   0    Brit Hotels London Court
# Name: hotel_name, dtype: object
#
# {'corpus_id': 25, 'score': 0.46648725867271423}
# (Score: 0.4665)
# httpwwwtripadvisorcomhotel_reviewg186338d9608180reviewsthe_z_hotel_citylondon_englandhtml
# paper_id:   25    The Z Hotel City
# Name: hotel_name, dtype: object
#
# {'corpus_id': 6, 'score': 0.4647839367389679}
# (Score: 0.4648)
# httpwwwtripadvisorcomhotel_reviewg186338d12938460reviewsibis_london_canning_townlondon_englandhtml
# paper_id:   6    Ibis London Canning Town
# Name: hotel_name, dtype: object
#
# {'corpus_id': 4, 'score': 0.4549912214279175}
# (Score: 0.4550)
# httpwwwtripadvisorcomhotel_reviewg186338d313125reviewsholiday_inn_london_westlondon_englandhtml
# paper_id:   4    Holiday Inn London - West
# Name: hotel_name, dtype: object
#
# ...

# %%
query_embedding.shape
# Out:
# torch.Size([768])

# %%
df
# Out:
#                                         hotel_name  \
# 0                         Brit Hotels London Court
# 1                            Charlotte Guest House
# 2            DoubleTree by Hilton London Greenwich
# 3               Hampton by Hilton London Docklands
# 4                        Holiday Inn London - West
# 5                                         Hotel 55
# 6                         Ibis London Canning Town
# 7   Ibis London Shepherds Bush - Hammersmith Hotel
# 8                         Kensington Gardens Hotel
# 9                          Lansbury Heritage Hotel
# 10                                   Montana Hotel
# 11                            Novotel London Excel
# 12                    Park Plaza London Park Royal
# 13              Pelican London Hotel and Residence
# 14    Point A Hotel, London Kings Cross St Pancras
# 15            Premier Inn London Hanger Lane Hotel
# 16                                St. Athans Hotel
# ...

# %% [markdown]
# End
